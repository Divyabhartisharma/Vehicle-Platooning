# %%
import cupy as cp
import time

class Truck:
    def __init__(self, name, speed, distance_to_front, distance_to_rear, platoon_speed):
        self.name = name
        self.speed = cp.array(speed, dtype='float32')
        self.distance_to_front = cp.array(distance_to_front, dtype='float32')
        self.distance_to_rear = cp.array(distance_to_rear, dtype='float32')
        self.platoon_speed = cp.array(platoon_speed, dtype='float32')

    def update_speed(self):
        # calculate new speed based on distance to front and rear trucks
        desired_distance_to_front = cp.array(50, dtype='float32')
        desired_distance_to_rear = cp.array(20, dtype='float32')
        acceleration = cp.array(2, dtype='float32')

        if self.distance_to_front > desired_distance_to_front:
            self.speed += acceleration
        elif self.distance_to_front < desired_distance_to_front:
            self.speed -= acceleration

        if self.distance_to_rear > desired_distance_to_rear:
            self.speed -= acceleration
        elif self.distance_to_rear < desired_distance_to_rear:
            self.speed += acceleration

        # adjust speed to stay within platoon speed
        self.speed = cp.minimum(self.speed, self.platoon_speed)

    def update_distance(self, time_diff, front_truck=None, rear_truck=None):
        # update distance based on time elapsed and speed
        self.distance_to_front -= self.speed * time_diff

        if front_truck is not None:
            self.distance_to_front += front_truck.speed * time_diff

        if rear_truck is not None:
            self.distance_to_rear += rear_truck.speed * time_diff

    def __str__(self):
        return f"{self.name}: speed={self.speed:.1f}, distance_to_front={self.distance_to_front:.1f}, distance_to_rear={self.distance_to_rear:.1f}"

def simulate_platoon():
    # create initial trucks
    truck1 = Truck("Truck 1", 70, 0, 50, 70)
    truck2 = Truck("Truck 2", 70, 50, 50, 70)
    truck3 = Truck("Truck 3", 70, 50, 0, 70)

    trucks = [truck1, truck2, truck3]

    while True:
        # update trucks
        for i in range(len(trucks)):
            truck = trucks[i]
            front_truck = None
            rear_truck = None

            if i > 0:
                front_truck = trucks[i-1]

            if i < len(trucks)-1:
                rear_truck = trucks[i+1]

            truck.update_speed()
            truck.update_distance(0.1, front_truck, rear_truck)

        # print truck states
        for truck in trucks:
            print(truck)

        print("-" * 40)
        time.sleep(0.1)

if __name__ == "__main__":
    simulate_platoon()
# Out:
# Truck 1: speed=66.0, distance_to_front=-6.6, distance_to_rear=57.0
# Truck 2: speed=68.0, distance_to_front=49.8, distance_to_rear=57.0
# Truck 3: speed=70.0, distance_to_front=49.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=62.0, distance_to_front=-12.8, distance_to_rear=63.8
# Truck 2: speed=64.0, distance_to_front=49.6, distance_to_rear=64.0
# Truck 3: speed=70.0, distance_to_front=49.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=58.0, distance_to_front=-18.6, distance_to_rear=70.2
# Truck 2: speed=60.0, distance_to_front=49.4, distance_to_rear=71.0
# Truck 3: speed=70.0, distance_to_front=48.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=54.0, distance_to_front=-24.0, distance_to_rear=76.2
# Truck 2: speed=56.0, distance_to_front=49.2, distance_to_rear=78.0
# Truck 3: speed=70.0, distance_to_front=46.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=50.0, distance_to_front=-29.0, distance_to_rear=81.8
# Truck 2: speed=52.0, distance_to_front=49.0, distance_to_rear=85.0
# Truck 3: speed=70.0, distance_to_front=45.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=46.0, distance_to_front=-33.6, distance_to_rear=87.0
# Truck 2: speed=48.0, distance_to_front=48.8, distance_to_rear=92.0
# Truck 3: speed=70.0, distance_to_front=42.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=42.0, distance_to_front=-37.8, distance_to_rear=91.8
# Truck 2: speed=44.0, distance_to_front=48.6, distance_to_rear=99.0
# Truck 3: speed=70.0, distance_to_front=40.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=38.0, distance_to_front=-41.6, distance_to_rear=96.2
# Truck 2: speed=40.0, distance_to_front=48.4, distance_to_rear=106.0
# Truck 3: speed=70.0, distance_to_front=37.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=34.0, distance_to_front=-45.0, distance_to_rear=100.2
# Truck 2: speed=36.0, distance_to_front=48.2, distance_to_rear=113.0
# Truck 3: speed=70.0, distance_to_front=33.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=30.0, distance_to_front=-48.0, distance_to_rear=103.8
# Truck 2: speed=32.0, distance_to_front=48.0, distance_to_rear=120.0
# Truck 3: speed=70.0, distance_to_front=30.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=26.0, distance_to_front=-50.6, distance_to_rear=107.0
# Truck 2: speed=28.0, distance_to_front=47.8, distance_to_rear=127.0
# Truck 3: speed=70.0, distance_to_front=25.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=22.0, distance_to_front=-52.8, distance_to_rear=109.8
# Truck 2: speed=24.0, distance_to_front=47.6, distance_to_rear=134.0
# Truck 3: speed=70.0, distance_to_front=21.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=18.0, distance_to_front=-54.6, distance_to_rear=112.2
# Truck 2: speed=20.0, distance_to_front=47.4, distance_to_rear=141.0
# Truck 3: speed=70.0, distance_to_front=16.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=14.0, distance_to_front=-56.0, distance_to_rear=114.2
# Truck 2: speed=16.0, distance_to_front=47.2, distance_to_rear=148.0
# Truck 3: speed=70.0, distance_to_front=10.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=10.0, distance_to_front=-57.0, distance_to_rear=115.8
# Truck 2: speed=12.0, distance_to_front=47.0, distance_to_rear=155.0
# Truck 3: speed=70.0, distance_to_front=5.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=6.0, distance_to_front=-57.6, distance_to_rear=117.0
# Truck 2: speed=8.0, distance_to_front=46.8, distance_to_rear=162.0
# Truck 3: speed=70.0, distance_to_front=-1.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=2.0, distance_to_front=-57.8, distance_to_rear=117.8
# Truck 2: speed=4.0, distance_to_front=46.6, distance_to_rear=169.0
# Truck 3: speed=70.0, distance_to_front=-7.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-2.0, distance_to_front=-57.6, distance_to_rear=118.2
# Truck 2: speed=0.0, distance_to_front=46.4, distance_to_rear=176.0
# Truck 3: speed=70.0, distance_to_front=-14.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-6.0, distance_to_front=-57.0, distance_to_rear=118.2
# Truck 2: speed=-4.0, distance_to_front=46.2, distance_to_rear=183.0
# Truck 3: speed=70.0, distance_to_front=-22.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-10.0, distance_to_front=-56.0, distance_to_rear=117.8
# Truck 2: speed=-8.0, distance_to_front=46.0, distance_to_rear=190.0
# Truck 3: speed=70.0, distance_to_front=-30.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-14.0, distance_to_front=-54.6, distance_to_rear=117.0
# Truck 2: speed=-12.0, distance_to_front=45.8, distance_to_rear=197.0
# Truck 3: speed=70.0, distance_to_front=-38.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-18.0, distance_to_front=-52.8, distance_to_rear=115.8
# Truck 2: speed=-16.0, distance_to_front=45.6, distance_to_rear=204.0
# Truck 3: speed=70.0, distance_to_front=-46.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-22.0, distance_to_front=-50.6, distance_to_rear=114.2
# Truck 2: speed=-20.0, distance_to_front=45.4, distance_to_rear=211.0
# Truck 3: speed=70.0, distance_to_front=-55.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-26.0, distance_to_front=-48.0, distance_to_rear=112.2
# Truck 2: speed=-24.0, distance_to_front=45.2, distance_to_rear=218.0
# Truck 3: speed=70.0, distance_to_front=-65.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-30.0, distance_to_front=-45.0, distance_to_rear=109.8
# Truck 2: speed=-28.0, distance_to_front=45.0, distance_to_rear=225.0
# Truck 3: speed=70.0, distance_to_front=-75.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-34.0, distance_to_front=-41.6, distance_to_rear=107.0
# Truck 2: speed=-32.0, distance_to_front=44.8, distance_to_rear=232.0
# Truck 3: speed=70.0, distance_to_front=-85.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-38.0, distance_to_front=-37.8, distance_to_rear=103.8
# Truck 2: speed=-36.0, distance_to_front=44.6, distance_to_rear=239.0
# Truck 3: speed=70.0, distance_to_front=-95.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-42.0, distance_to_front=-33.6, distance_to_rear=100.2
# Truck 2: speed=-40.0, distance_to_front=44.4, distance_to_rear=246.0
# Truck 3: speed=70.0, distance_to_front=-106.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-46.0, distance_to_front=-29.0, distance_to_rear=96.2
# Truck 2: speed=-44.0, distance_to_front=44.2, distance_to_rear=253.0
# Truck 3: speed=70.0, distance_to_front=-118.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-50.0, distance_to_front=-24.0, distance_to_rear=91.8
# Truck 2: speed=-48.0, distance_to_front=44.0, distance_to_rear=260.0
# Truck 3: speed=70.0, distance_to_front=-130.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-54.0, distance_to_front=-18.6, distance_to_rear=87.0
# Truck 2: speed=-52.0, distance_to_front=43.8, distance_to_rear=267.0
# Truck 3: speed=70.0, distance_to_front=-142.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-58.0, distance_to_front=-12.8, distance_to_rear=81.8
# Truck 2: speed=-56.0, distance_to_front=43.6, distance_to_rear=274.0
# Truck 3: speed=70.0, distance_to_front=-154.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-62.0, distance_to_front=-6.6, distance_to_rear=76.2
# Truck 2: speed=-60.0, distance_to_front=43.4, distance_to_rear=281.0
# Truck 3: speed=70.0, distance_to_front=-167.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-66.0, distance_to_front=0.0, distance_to_rear=70.2
# Truck 2: speed=-64.0, distance_to_front=43.2, distance_to_rear=288.0
# Truck 3: speed=70.0, distance_to_front=-181.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-70.0, distance_to_front=7.0, distance_to_rear=63.8
# Truck 2: speed=-68.0, distance_to_front=43.0, distance_to_rear=295.0
# Truck 3: speed=70.0, distance_to_front=-195.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-74.0, distance_to_front=14.4, distance_to_rear=57.0
# Truck 2: speed=-72.0, distance_to_front=42.8, distance_to_rear=302.0
# Truck 3: speed=70.0, distance_to_front=-209.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-78.0, distance_to_front=22.2, distance_to_rear=49.8
# Truck 2: speed=-76.0, distance_to_front=42.6, distance_to_rear=309.0
# Truck 3: speed=70.0, distance_to_front=-223.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-82.0, distance_to_front=30.4, distance_to_rear=42.2
# Truck 2: speed=-80.0, distance_to_front=42.4, distance_to_rear=316.0
# Truck 3: speed=70.0, distance_to_front=-238.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-86.0, distance_to_front=39.0, distance_to_rear=34.2
# Truck 2: speed=-84.0, distance_to_front=42.2, distance_to_rear=323.0
# Truck 3: speed=70.0, distance_to_front=-254.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-90.0, distance_to_front=48.0, distance_to_rear=25.8
# Truck 2: speed=-88.0, distance_to_front=42.0, distance_to_rear=330.0
# Truck 3: speed=70.0, distance_to_front=-270.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-94.0, distance_to_front=57.4, distance_to_rear=17.0
# Truck 2: speed=-92.0, distance_to_front=41.8, distance_to_rear=337.0
# Truck 3: speed=70.0, distance_to_front=-286.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-90.0, distance_to_front=66.4, distance_to_rear=7.8
# Truck 2: speed=-96.0, distance_to_front=42.4, distance_to_rear=344.0
# Truck 3: speed=70.0, distance_to_front=-302.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-86.0, distance_to_front=75.0, distance_to_rear=-1.8
# Truck 2: speed=-100.0, distance_to_front=43.8, distance_to_rear=351.0
# Truck 3: speed=70.0, distance_to_front=-319.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-82.0, distance_to_front=83.2, distance_to_rear=-11.8
# Truck 2: speed=-104.0, distance_to_front=46.0, distance_to_rear=358.0
# Truck 3: speed=70.0, distance_to_front=-337.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-78.0, distance_to_front=91.0, distance_to_rear=-22.2
# Truck 2: speed=-108.0, distance_to_front=49.0, distance_to_rear=365.0
# Truck 3: speed=70.0, distance_to_front=-355.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-74.0, distance_to_front=98.4, distance_to_rear=-33.0
# Truck 2: speed=-112.0, distance_to_front=52.8, distance_to_rear=372.0
# Truck 3: speed=70.0, distance_to_front=-373.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-70.0, distance_to_front=105.4, distance_to_rear=-44.2
# Truck 2: speed=-112.0, distance_to_front=57.0, distance_to_rear=379.0
# Truck 3: speed=70.0, distance_to_front=-391.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-66.0, distance_to_front=112.0, distance_to_rear=-55.4
# Truck 2: speed=-112.0, distance_to_front=61.6, distance_to_rear=386.0
# Truck 3: speed=70.0, distance_to_front=-409.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-62.0, distance_to_front=118.2, distance_to_rear=-66.6
# Truck 2: speed=-112.0, distance_to_front=66.6, distance_to_rear=393.0
# Truck 3: speed=70.0, distance_to_front=-427.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-58.0, distance_to_front=124.0, distance_to_rear=-77.8
# Truck 2: speed=-112.0, distance_to_front=72.0, distance_to_rear=400.0
# Truck 3: speed=70.0, distance_to_front=-446.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-54.0, distance_to_front=129.4, distance_to_rear=-89.0
# Truck 2: speed=-112.0, distance_to_front=77.8, distance_to_rear=407.0
# Truck 3: speed=70.0, distance_to_front=-464.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-50.0, distance_to_front=134.4, distance_to_rear=-100.2
# Truck 2: speed=-112.0, distance_to_front=84.0, distance_to_rear=414.0
# Truck 3: speed=70.0, distance_to_front=-482.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-46.0, distance_to_front=139.0, distance_to_rear=-111.4
# Truck 2: speed=-112.0, distance_to_front=90.6, distance_to_rear=421.0
# Truck 3: speed=70.0, distance_to_front=-500.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-42.0, distance_to_front=143.2, distance_to_rear=-122.6
# Truck 2: speed=-112.0, distance_to_front=97.6, distance_to_rear=428.0
# Truck 3: speed=70.0, distance_to_front=-518.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-38.0, distance_to_front=147.0, distance_to_rear=-133.8
# Truck 2: speed=-112.0, distance_to_front=105.0, distance_to_rear=435.0
# Truck 3: speed=70.0, distance_to_front=-537.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-34.0, distance_to_front=150.4, distance_to_rear=-145.0
# Truck 2: speed=-112.0, distance_to_front=112.8, distance_to_rear=442.0
# Truck 3: speed=70.0, distance_to_front=-555.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-30.0, distance_to_front=153.4, distance_to_rear=-156.2
# Truck 2: speed=-112.0, distance_to_front=121.0, distance_to_rear=449.0
# Truck 3: speed=70.0, distance_to_front=-573.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-26.0, distance_to_front=156.0, distance_to_rear=-167.4
# Truck 2: speed=-112.0, distance_to_front=129.6, distance_to_rear=456.0
# Truck 3: speed=70.0, distance_to_front=-591.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-22.0, distance_to_front=158.2, distance_to_rear=-178.6
# Truck 2: speed=-112.0, distance_to_front=138.6, distance_to_rear=463.0
# Truck 3: speed=70.0, distance_to_front=-609.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-18.0, distance_to_front=160.0, distance_to_rear=-189.8
# Truck 2: speed=-112.0, distance_to_front=148.0, distance_to_rear=470.0
# Truck 3: speed=70.0, distance_to_front=-628.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-14.0, distance_to_front=161.4, distance_to_rear=-201.0
# Truck 2: speed=-112.0, distance_to_front=157.8, distance_to_rear=477.0
# Truck 3: speed=70.0, distance_to_front=-646.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-10.0, distance_to_front=162.4, distance_to_rear=-212.2
# Truck 2: speed=-112.0, distance_to_front=168.0, distance_to_rear=484.0
# Truck 3: speed=70.0, distance_to_front=-664.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-6.0, distance_to_front=163.0, distance_to_rear=-223.4
# Truck 2: speed=-112.0, distance_to_front=178.6, distance_to_rear=491.0
# Truck 3: speed=70.0, distance_to_front=-682.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=-2.0, distance_to_front=163.2, distance_to_rear=-234.6
# Truck 2: speed=-112.0, distance_to_front=189.6, distance_to_rear=498.0
# Truck 3: speed=70.0, distance_to_front=-700.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=2.0, distance_to_front=163.0, distance_to_rear=-245.8
# Truck 2: speed=-112.0, distance_to_front=201.0, distance_to_rear=505.0
# Truck 3: speed=70.0, distance_to_front=-719.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=6.0, distance_to_front=162.4, distance_to_rear=-257.0
# Truck 2: speed=-112.0, distance_to_front=212.8, distance_to_rear=512.0
# Truck 3: speed=70.0, distance_to_front=-737.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=10.0, distance_to_front=161.4, distance_to_rear=-268.2
# Truck 2: speed=-112.0, distance_to_front=225.0, distance_to_rear=519.0
# Truck 3: speed=70.0, distance_to_front=-755.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=14.0, distance_to_front=160.0, distance_to_rear=-279.4
# Truck 2: speed=-112.0, distance_to_front=237.6, distance_to_rear=526.0
# Truck 3: speed=70.0, distance_to_front=-773.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=18.0, distance_to_front=158.2, distance_to_rear=-290.6
# Truck 2: speed=-112.0, distance_to_front=250.6, distance_to_rear=533.0
# Truck 3: speed=70.0, distance_to_front=-791.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=22.0, distance_to_front=156.0, distance_to_rear=-301.8
# Truck 2: speed=-112.0, distance_to_front=264.0, distance_to_rear=540.0
# Truck 3: speed=70.0, distance_to_front=-810.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=26.0, distance_to_front=153.4, distance_to_rear=-313.0
# Truck 2: speed=-112.0, distance_to_front=277.8, distance_to_rear=547.0
# Truck 3: speed=70.0, distance_to_front=-828.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=30.0, distance_to_front=150.4, distance_to_rear=-324.2
# Truck 2: speed=-112.0, distance_to_front=292.0, distance_to_rear=554.0
# Truck 3: speed=70.0, distance_to_front=-846.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=34.0, distance_to_front=147.0, distance_to_rear=-335.4
# Truck 2: speed=-112.0, distance_to_front=306.6, distance_to_rear=561.0
# Truck 3: speed=70.0, distance_to_front=-864.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=38.0, distance_to_front=143.2, distance_to_rear=-346.6
# Truck 2: speed=-112.0, distance_to_front=321.6, distance_to_rear=568.0
# Truck 3: speed=70.0, distance_to_front=-882.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=42.0, distance_to_front=139.0, distance_to_rear=-357.8
# Truck 2: speed=-112.0, distance_to_front=337.0, distance_to_rear=575.0
# Truck 3: speed=70.0, distance_to_front=-901.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=46.0, distance_to_front=134.4, distance_to_rear=-369.0
# Truck 2: speed=-112.0, distance_to_front=352.8, distance_to_rear=582.0
# Truck 3: speed=70.0, distance_to_front=-919.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=50.0, distance_to_front=129.4, distance_to_rear=-380.2
# Truck 2: speed=-112.0, distance_to_front=369.0, distance_to_rear=589.0
# Truck 3: speed=70.0, distance_to_front=-937.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=54.0, distance_to_front=124.0, distance_to_rear=-391.4
# Truck 2: speed=-112.0, distance_to_front=385.6, distance_to_rear=596.0
# Truck 3: speed=70.0, distance_to_front=-955.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=58.0, distance_to_front=118.2, distance_to_rear=-402.6
# Truck 2: speed=-112.0, distance_to_front=402.6, distance_to_rear=603.0
# Truck 3: speed=70.0, distance_to_front=-973.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=62.0, distance_to_front=112.0, distance_to_rear=-413.8
# Truck 2: speed=-112.0, distance_to_front=420.0, distance_to_rear=610.0
# Truck 3: speed=70.0, distance_to_front=-992.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=66.0, distance_to_front=105.4, distance_to_rear=-425.0
# Truck 2: speed=-112.0, distance_to_front=437.8, distance_to_rear=617.0
# Truck 3: speed=70.0, distance_to_front=-1010.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=98.4, distance_to_rear=-436.2
# Truck 2: speed=-112.0, distance_to_front=456.0, distance_to_rear=624.0
# Truck 3: speed=70.0, distance_to_front=-1028.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=91.4, distance_to_rear=-447.4
# Truck 2: speed=-112.0, distance_to_front=474.2, distance_to_rear=631.0
# Truck 3: speed=70.0, distance_to_front=-1046.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=84.4, distance_to_rear=-458.6
# Truck 2: speed=-112.0, distance_to_front=492.4, distance_to_rear=638.0
# Truck 3: speed=70.0, distance_to_front=-1064.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=77.4, distance_to_rear=-469.8
# Truck 2: speed=-112.0, distance_to_front=510.6, distance_to_rear=645.0
# Truck 3: speed=70.0, distance_to_front=-1083.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=70.4, distance_to_rear=-481.0
# Truck 2: speed=-112.0, distance_to_front=528.8, distance_to_rear=652.0
# Truck 3: speed=70.0, distance_to_front=-1101.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=63.4, distance_to_rear=-492.2
# Truck 2: speed=-112.0, distance_to_front=547.0, distance_to_rear=659.0
# Truck 3: speed=70.0, distance_to_front=-1119.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=56.4, distance_to_rear=-503.4
# Truck 2: speed=-112.0, distance_to_front=565.2, distance_to_rear=666.0
# Truck 3: speed=70.0, distance_to_front=-1137.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=49.4, distance_to_rear=-514.6
# Truck 2: speed=-112.0, distance_to_front=583.4, distance_to_rear=673.0
# Truck 3: speed=70.0, distance_to_front=-1155.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=42.4, distance_to_rear=-525.8
# Truck 2: speed=-112.0, distance_to_front=601.6, distance_to_rear=680.0
# Truck 3: speed=70.0, distance_to_front=-1174.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=35.4, distance_to_rear=-537.0
# Truck 2: speed=-112.0, distance_to_front=619.8, distance_to_rear=687.0
# Truck 3: speed=70.0, distance_to_front=-1192.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=28.4, distance_to_rear=-548.2
# Truck 2: speed=-112.0, distance_to_front=638.0, distance_to_rear=694.0
# Truck 3: speed=70.0, distance_to_front=-1210.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=21.4, distance_to_rear=-559.4
# Truck 2: speed=-112.0, distance_to_front=656.2, distance_to_rear=701.0
# Truck 3: speed=70.0, distance_to_front=-1228.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=14.4, distance_to_rear=-570.6
# Truck 2: speed=-112.0, distance_to_front=674.4, distance_to_rear=708.0
# Truck 3: speed=70.0, distance_to_front=-1246.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=7.4, distance_to_rear=-581.8
# Truck 2: speed=-112.0, distance_to_front=692.6, distance_to_rear=715.0
# Truck 3: speed=70.0, distance_to_front=-1265.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=0.4, distance_to_rear=-593.0
# Truck 2: speed=-112.0, distance_to_front=710.8, distance_to_rear=722.0
# Truck 3: speed=70.0, distance_to_front=-1283.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-6.6, distance_to_rear=-604.2
# Truck 2: speed=-112.0, distance_to_front=729.0, distance_to_rear=729.0
# Truck 3: speed=70.0, distance_to_front=-1301.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-13.6, distance_to_rear=-615.4
# Truck 2: speed=-112.0, distance_to_front=747.2, distance_to_rear=736.0
# Truck 3: speed=70.0, distance_to_front=-1319.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-20.6, distance_to_rear=-626.6
# Truck 2: speed=-112.0, distance_to_front=765.4, distance_to_rear=743.0
# Truck 3: speed=70.0, distance_to_front=-1337.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-27.6, distance_to_rear=-637.8
# Truck 2: speed=-112.0, distance_to_front=783.6, distance_to_rear=750.0
# Truck 3: speed=70.0, distance_to_front=-1356.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-34.6, distance_to_rear=-649.0
# Truck 2: speed=-112.0, distance_to_front=801.8, distance_to_rear=757.0
# Truck 3: speed=70.0, distance_to_front=-1374.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-41.6, distance_to_rear=-660.2
# Truck 2: speed=-112.0, distance_to_front=820.0, distance_to_rear=764.0
# Truck 3: speed=70.0, distance_to_front=-1392.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-48.6, distance_to_rear=-671.4
# Truck 2: speed=-112.0, distance_to_front=838.2, distance_to_rear=771.0
# Truck 3: speed=70.0, distance_to_front=-1410.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-55.6, distance_to_rear=-682.6
# Truck 2: speed=-112.0, distance_to_front=856.4, distance_to_rear=778.0
# Truck 3: speed=70.0, distance_to_front=-1428.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-62.6, distance_to_rear=-693.8
# Truck 2: speed=-112.0, distance_to_front=874.6, distance_to_rear=785.0
# Truck 3: speed=70.0, distance_to_front=-1447.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-69.6, distance_to_rear=-705.0
# Truck 2: speed=-112.0, distance_to_front=892.8, distance_to_rear=792.0
# Truck 3: speed=70.0, distance_to_front=-1465.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-76.6, distance_to_rear=-716.2
# Truck 2: speed=-112.0, distance_to_front=911.0, distance_to_rear=799.0
# Truck 3: speed=70.0, distance_to_front=-1483.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-83.6, distance_to_rear=-727.4
# Truck 2: speed=-112.0, distance_to_front=929.2, distance_to_rear=806.0
# Truck 3: speed=70.0, distance_to_front=-1501.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-90.6, distance_to_rear=-738.6
# Truck 2: speed=-112.0, distance_to_front=947.4, distance_to_rear=813.0
# Truck 3: speed=70.0, distance_to_front=-1519.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-97.6, distance_to_rear=-749.8
# Truck 2: speed=-112.0, distance_to_front=965.6, distance_to_rear=820.0
# Truck 3: speed=70.0, distance_to_front=-1538.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-104.6, distance_to_rear=-761.0
# Truck 2: speed=-112.0, distance_to_front=983.8, distance_to_rear=827.0
# Truck 3: speed=70.0, distance_to_front=-1556.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-111.6, distance_to_rear=-772.2
# Truck 2: speed=-112.0, distance_to_front=1002.0, distance_to_rear=834.0
# Truck 3: speed=70.0, distance_to_front=-1574.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-118.6, distance_to_rear=-783.4
# Truck 2: speed=-112.0, distance_to_front=1020.2, distance_to_rear=841.0
# Truck 3: speed=70.0, distance_to_front=-1592.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-125.6, distance_to_rear=-794.6
# Truck 2: speed=-112.0, distance_to_front=1038.4, distance_to_rear=848.0
# Truck 3: speed=70.0, distance_to_front=-1610.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-132.6, distance_to_rear=-805.8
# Truck 2: speed=-112.0, distance_to_front=1056.6, distance_to_rear=855.0
# Truck 3: speed=70.0, distance_to_front=-1629.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-139.6, distance_to_rear=-817.0
# Truck 2: speed=-112.0, distance_to_front=1074.8, distance_to_rear=862.0
# Truck 3: speed=70.0, distance_to_front=-1647.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-146.6, distance_to_rear=-828.2
# Truck 2: speed=-112.0, distance_to_front=1093.0, distance_to_rear=869.0
# Truck 3: speed=70.0, distance_to_front=-1665.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-153.6, distance_to_rear=-839.4
# Truck 2: speed=-112.0, distance_to_front=1111.2, distance_to_rear=876.0
# Truck 3: speed=70.0, distance_to_front=-1683.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-160.6, distance_to_rear=-850.6
# Truck 2: speed=-112.0, distance_to_front=1129.4, distance_to_rear=883.0
# Truck 3: speed=70.0, distance_to_front=-1701.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-167.6, distance_to_rear=-861.8
# Truck 2: speed=-112.0, distance_to_front=1147.6, distance_to_rear=890.0
# Truck 3: speed=70.0, distance_to_front=-1720.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-174.6, distance_to_rear=-873.0
# Truck 2: speed=-112.0, distance_to_front=1165.8, distance_to_rear=897.0
# Truck 3: speed=70.0, distance_to_front=-1738.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-181.6, distance_to_rear=-884.2
# Truck 2: speed=-112.0, distance_to_front=1184.0, distance_to_rear=904.0
# Truck 3: speed=70.0, distance_to_front=-1756.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-188.6, distance_to_rear=-895.4
# Truck 2: speed=-112.0, distance_to_front=1202.2, distance_to_rear=911.0
# Truck 3: speed=70.0, distance_to_front=-1774.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-195.6, distance_to_rear=-906.6
# Truck 2: speed=-112.0, distance_to_front=1220.4, distance_to_rear=918.0
# Truck 3: speed=70.0, distance_to_front=-1792.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-202.6, distance_to_rear=-917.8
# Truck 2: speed=-112.0, distance_to_front=1238.6, distance_to_rear=925.0
# Truck 3: speed=70.0, distance_to_front=-1811.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-209.6, distance_to_rear=-929.0
# Truck 2: speed=-112.0, distance_to_front=1256.8, distance_to_rear=932.0
# Truck 3: speed=70.0, distance_to_front=-1829.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-216.6, distance_to_rear=-940.2
# Truck 2: speed=-112.0, distance_to_front=1275.0, distance_to_rear=939.0
# Truck 3: speed=70.0, distance_to_front=-1847.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-223.6, distance_to_rear=-951.4
# Truck 2: speed=-112.0, distance_to_front=1293.2, distance_to_rear=946.0
# Truck 3: speed=70.0, distance_to_front=-1865.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-230.6, distance_to_rear=-962.6
# Truck 2: speed=-112.0, distance_to_front=1311.4, distance_to_rear=953.0
# Truck 3: speed=70.0, distance_to_front=-1883.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-237.6, distance_to_rear=-973.8
# Truck 2: speed=-112.0, distance_to_front=1329.6, distance_to_rear=960.0
# Truck 3: speed=70.0, distance_to_front=-1902.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-244.6, distance_to_rear=-985.0
# Truck 2: speed=-112.0, distance_to_front=1347.8, distance_to_rear=967.0
# Truck 3: speed=70.0, distance_to_front=-1920.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-251.6, distance_to_rear=-996.2
# Truck 2: speed=-112.0, distance_to_front=1366.0, distance_to_rear=974.0
# Truck 3: speed=70.0, distance_to_front=-1938.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-258.6, distance_to_rear=-1007.4
# Truck 2: speed=-112.0, distance_to_front=1384.2, distance_to_rear=981.0
# Truck 3: speed=70.0, distance_to_front=-1956.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-265.6, distance_to_rear=-1018.6
# Truck 2: speed=-112.0, distance_to_front=1402.4, distance_to_rear=988.0
# Truck 3: speed=70.0, distance_to_front=-1974.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-272.6, distance_to_rear=-1029.8
# Truck 2: speed=-112.0, distance_to_front=1420.6, distance_to_rear=995.0
# Truck 3: speed=70.0, distance_to_front=-1993.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-279.6, distance_to_rear=-1041.0
# Truck 2: speed=-112.0, distance_to_front=1438.8, distance_to_rear=1002.0
# Truck 3: speed=70.0, distance_to_front=-2011.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-286.6, distance_to_rear=-1052.2
# Truck 2: speed=-112.0, distance_to_front=1457.0, distance_to_rear=1009.0
# Truck 3: speed=70.0, distance_to_front=-2029.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-293.6, distance_to_rear=-1063.4
# Truck 2: speed=-112.0, distance_to_front=1475.2, distance_to_rear=1016.0
# Truck 3: speed=70.0, distance_to_front=-2047.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-300.6, distance_to_rear=-1074.6
# Truck 2: speed=-112.0, distance_to_front=1493.4, distance_to_rear=1023.0
# Truck 3: speed=70.0, distance_to_front=-2065.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-307.6, distance_to_rear=-1085.8
# Truck 2: speed=-112.0, distance_to_front=1511.6, distance_to_rear=1030.0
# Truck 3: speed=70.0, distance_to_front=-2084.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-314.6, distance_to_rear=-1097.0
# Truck 2: speed=-112.0, distance_to_front=1529.8, distance_to_rear=1037.0
# Truck 3: speed=70.0, distance_to_front=-2102.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-321.6, distance_to_rear=-1108.2
# Truck 2: speed=-112.0, distance_to_front=1548.0, distance_to_rear=1044.0
# Truck 3: speed=70.0, distance_to_front=-2120.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-328.6, distance_to_rear=-1119.4
# Truck 2: speed=-112.0, distance_to_front=1566.2, distance_to_rear=1051.0
# Truck 3: speed=70.0, distance_to_front=-2138.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-335.6, distance_to_rear=-1130.6
# Truck 2: speed=-112.0, distance_to_front=1584.4, distance_to_rear=1058.0
# Truck 3: speed=70.0, distance_to_front=-2156.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-342.6, distance_to_rear=-1141.8
# Truck 2: speed=-112.0, distance_to_front=1602.6, distance_to_rear=1065.0
# Truck 3: speed=70.0, distance_to_front=-2175.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-349.6, distance_to_rear=-1153.0
# Truck 2: speed=-112.0, distance_to_front=1620.8, distance_to_rear=1072.0
# Truck 3: speed=70.0, distance_to_front=-2193.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-356.6, distance_to_rear=-1164.2
# Truck 2: speed=-112.0, distance_to_front=1639.0, distance_to_rear=1079.0
# Truck 3: speed=70.0, distance_to_front=-2211.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-363.6, distance_to_rear=-1175.4
# Truck 2: speed=-112.0, distance_to_front=1657.2, distance_to_rear=1086.0
# Truck 3: speed=70.0, distance_to_front=-2229.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-370.6, distance_to_rear=-1186.6
# Truck 2: speed=-112.0, distance_to_front=1675.4, distance_to_rear=1093.0
# Truck 3: speed=70.0, distance_to_front=-2247.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-377.6, distance_to_rear=-1197.8
# Truck 2: speed=-112.0, distance_to_front=1693.6, distance_to_rear=1100.0
# Truck 3: speed=70.0, distance_to_front=-2266.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-384.6, distance_to_rear=-1209.0
# Truck 2: speed=-112.0, distance_to_front=1711.8, distance_to_rear=1107.0
# Truck 3: speed=70.0, distance_to_front=-2284.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-391.6, distance_to_rear=-1220.2
# Truck 2: speed=-112.0, distance_to_front=1730.0, distance_to_rear=1114.0
# Truck 3: speed=70.0, distance_to_front=-2302.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-398.6, distance_to_rear=-1231.4
# Truck 2: speed=-112.0, distance_to_front=1748.2, distance_to_rear=1121.0
# Truck 3: speed=70.0, distance_to_front=-2320.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-405.6, distance_to_rear=-1242.6
# Truck 2: speed=-112.0, distance_to_front=1766.4, distance_to_rear=1128.0
# Truck 3: speed=70.0, distance_to_front=-2338.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-412.6, distance_to_rear=-1253.8
# Truck 2: speed=-112.0, distance_to_front=1784.6, distance_to_rear=1135.0
# Truck 3: speed=70.0, distance_to_front=-2357.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-419.6, distance_to_rear=-1265.0
# Truck 2: speed=-112.0, distance_to_front=1802.8, distance_to_rear=1142.0
# Truck 3: speed=70.0, distance_to_front=-2375.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-426.6, distance_to_rear=-1276.2
# Truck 2: speed=-112.0, distance_to_front=1821.0, distance_to_rear=1149.0
# Truck 3: speed=70.0, distance_to_front=-2393.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-433.6, distance_to_rear=-1287.4
# Truck 2: speed=-112.0, distance_to_front=1839.2, distance_to_rear=1156.0
# Truck 3: speed=70.0, distance_to_front=-2411.6, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-440.6, distance_to_rear=-1298.6
# Truck 2: speed=-112.0, distance_to_front=1857.4, distance_to_rear=1163.0
# Truck 3: speed=70.0, distance_to_front=-2429.8, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-447.6, distance_to_rear=-1309.8
# Truck 2: speed=-112.0, distance_to_front=1875.6, distance_to_rear=1170.0
# Truck 3: speed=70.0, distance_to_front=-2448.0, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-454.6, distance_to_rear=-1321.0
# Truck 2: speed=-112.0, distance_to_front=1893.8, distance_to_rear=1177.0
# Truck 3: speed=70.0, distance_to_front=-2466.2, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-461.6, distance_to_rear=-1332.2
# Truck 2: speed=-112.0, distance_to_front=1912.0, distance_to_rear=1184.0
# Truck 3: speed=70.0, distance_to_front=-2484.4, distance_to_rear=0.0
# ----------------------------------------
# Truck 1: speed=70.0, distance_to_front=-468.6, distance_to_rear=-1343.4
# Truck 2: speed=-112.0, distance_to_front=1930.2, distance_to_rear=1191.0
# Truck 3: speed=70.0, distance_to_front=-2502.6, distance_to_rear=0.0
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-6217c0a240cd> in <module>
#      74
#      75 if __name__ == "__main__":
# ---> 76     simulate_platoon()
#
# <ipython-input-1-6217c0a240cd> in simulate_platoon()
#      71
#      72         print("-" * 40)
# ---> 73         time.sleep(0.1)
#      74
#      75 if __name__ == "__main__":
#
# KeyboardInterrupt:
